# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bayes_uni_grammes = [0.673, 0.646, 0.658, 0.667]
bayes_bi_grammes = [0.280, 0.275, 0.273, 0.278]
bayes_both = [0.669, 0.680, 0.653, 0.648]


import matplotlib.pyplot as plt

data = {
    'NAIVE MODEL': 0.33,

    'frequence, sans, uni-gramme': 0.673,
    'presence, sans, uni-gramme': 0.646,    
    'frequence, avec, uni-gramme': 0.678,
    'presence, avec, uni-gramme':0.687,
    'frequence, avec, bi-gramme':0.280,
    'presence, avec, bi-gramme':0.275,
    'frequence, sans, bi-gramme':0.278,
    'presence, sans, bi-gramme':0.273,
    'frequence, avec, both':0.669,
    'presence, avec, both':0.680,
    'frequence, sans, both':0.653,
    'presence, sans, both':0.648
}

variations = list(data.keys())
scores = list(data.values())

plt.figure(figsize=(10, 6))
plt.bar(variations, scores, color='blue')
plt.xlabel('Variations')
plt.ylabel('Mean CV Score')
plt.title('Naive-Bayes : Accuracy Score for Different Variations (var1, var2, var3)')
plt.xticks(rotation=90)
plt.show()

# %%
data = {
    '2, levenshtein, majoritaire': 0.776,
    '2, lcs, majoritaire': 0.793,
    '2, demerau-levenshtein, majoritaire': 0.774,
    '2, jaro, majoritaire':0.700,
    '2, cosine, majoritaire':0.318,
    '2, jaccard, majoritaire':0.301,
    '2, sorensen-dice, majoritaire':0.301,
    '2, q-gram dice, majoritaire':0.27,
    '2, q-gram dice, pondéré':0.297,
    '3, q-gram dice, pondéré':0.299,
}

variations = list(data.keys())
scores = list(data.values())

plt.figure(figsize=(10, 6))
plt.bar(variations, scores, color='blue')
plt.xlabel('Variations')
plt.ylabel('Mean CV Score')
plt.title('KNN : Accuracy Score for Different Variations (k, distance, vote)')
plt.xticks(rotation=90)
plt.show()
